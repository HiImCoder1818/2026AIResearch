# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
PATH = "~/RL-research/2026AIResearch/data/training_curves/dataPPO.csv"

df = pd.read_csv(PATH)
data_list = df.to_dict(orient='list')

plt.plot(data_list["timestep"], data_list["reward"], color="blue")

plt.xlabel("Timesteps")
plt.ylabel("Reward")
plt.legend()
# Out:
# /tmp/ipykernel_13674/2440288803.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
